# %% [markdown]
# # Sinusoid forecasting

# %% [markdown]
# ## The imports

# %%
# %matplotlib inline
import scipy
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from influxdb import InfluxDBClient
from influxdb import DataFrameClient
from apiclass import *
from statsmodels.tsa.holtwinters import ExponentialSmoothing, Holt
from sklearn.metrics import mean_squared_error as mse
from pylab import rcParams
from scipy.fftpack import fft

# %%
import sys
import warnings
import pickle
from math import *
if not sys.warnoptions:
    warnings.simplefilter("ignore")

# %%
import tensorflow as tf

# %% [markdown]
# ## Body

# %%
#
'''
### Dataframe extraction
query_body = """
SELECT  value

FROM meas
"""
########The database to retrieve data from ML######################
zhost = '192.168.4.33'
zport = 8086
zuser = ''
zpassword = ''
zdb_name = 'db'

#starttime = time.time()
#writer_client = DataFrameClient(host=zhost, port=zport, username=zuser, password=zpassword, database=db_name)
predictor = Online_predictor(zhost, zport, zuser, zpassword, zdb_name,query_body)
predictor.get_data_from_influx()
predictor.read_data()
df = predictor.prepare_data()
#print(df.ngp)
'''

# %%
df = pd.read_csv("db1.autogen.Thread-Gen-1.2018-11-07-10-12.csv")
df = df["Thread-Gen-1.mean_sinusoid"]
rcParams['figure.figsize'] = 20,5
plt.plot(df)
print(df.shape)
# Out:
# (361,)

# %%
def serialize(param_data, filename,train_idx=slice(97000,100000),test_idx=slice(100000,103000), seasonal_periods=314):
    train, test = param_data.iloc[train_idx], param_data.iloc[test_idx]
    param_data.index.freq = 'sec'
### Holts-winters exponential smoothing
    model = ExponentialSmoothing(train,seasonal='add',seasonal_periods=seasonal_periods).fit()
    pred = model.predict(start=test.index[0], end=test.index[-1])
    with open('%s.pickle' %filename, 'wb') as handle:
        pickle.dump(model, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
### This function loads the model, makes a prediction and plots it.
def performance(param_data, filename):
    with open('%s.pickle'%filename, 'rb') as handle:
        model1 = pickle.load(handle)
        pred = model1.predict(start=200, end=350)#param_data.index[-1])
    plt.rcParams["figure.figsize"] = 20,5
    #plt.plot(train.index, train, label='Train')
    plt.plot(param_data.iloc[200:350], label='Test')
    plt.plot(pred, label='Holt-Winters')
    plt.legend(loc='best')
    plt.show()
    print(mse(pred,param_data.iloc[200:350]))

# %%
train_idx=slice(0,200)
test_idx=slice(200,350)

# %%
serialize(df ,'value',train_idx,test_idx,seasonal_periods=36)
performance(df,'value')

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-9c6f879be384> in <module>()
# ----> 1 performance(df,'value')
#
# <ipython-input-22-b97a9315bc53> in performance(param_data, filename)
#      10     plt.legend(loc='best')
#      11     plt.show()
# ---> 12     print(mse(pred,param_data.iloc[200:350]))
#
# ~/practice1/lib/python3.6/site-packages/sklearn/metrics/regression.py in mean_squared_error(y_true, y_pred, sample_weight, multioutput)
#     237     """
#     238     y_type, y_true, y_pred, multioutput = _check_reg_targets(
# --> 239         y_true, y_pred, multioutput)
#     240     check_consistent_length(y_true, y_pred, sample_weight)
#     241     output_errors = np.average((y_true - y_pred) ** 2, axis=0,
#
# ~/practice1/lib/python3.6/site-packages/sklearn/metrics/regression.py in _check_reg_targets(y_true, y_pred, multioutput)
#      73
#      74     """
# ---> 75     check_consistent_length(y_true, y_pred)
#      76     y_true = check_array(y_true, ensure_2d=False)
#      77     y_pred = check_array(y_pred, ensure_2d=False)
#
# ~/practice1/lib/python3.6/site-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     228     if len(uniques) > 1:
#     229         raise ValueError("Found input variables with inconsistent numbers of"
# --> 230                          " samples: %r" % [int(l) for l in lengths])
#     231
#     232
#
# ValueError: Found input variables with inconsistent numbers of samples: [151, 150]

# %%
y = fft(df_v)
